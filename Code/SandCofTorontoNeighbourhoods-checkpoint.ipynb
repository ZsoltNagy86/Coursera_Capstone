# %% [markdown]
# # <span style="color:purple">Segmenting and Clustering Neighborhoods in Toronto</span>

# %% [markdown]
# ### <span style="color:darkred">Importing packages</span>

# %%
# Importing general packages
import pandas as pd
import dfply

from dfply import *
import numpy as np

# Importing packages for vizualization
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
import seaborn as sns

# Importing packages for scraping
#!conda install -c conda-forge wikipedia --yes 
import wikipedia
#!conda install -c conda-forge requests --yes 
import requests
#!conda install -c conda-forge bs4 --yes 
from bs4 import BeautifulSoup

# Importing packages for handling gespatial data
#!conda install -c conda-forge geocoder --yes 
import geocoder
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
import folium # map rendering library

# Packages for hiding sensitive data
from IPython.display import HTML

# Importing k-means from clustering stage
from sklearn.cluster import KMeans

# %% [markdown]
# ### <span style="color:darkred">Scraping wiki page for data about Canada's Borough/span>

# %%
html = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

#turn the HTML into a soup text object
bs = BeautifulSoup(html.text, 'lxml')

# %%
#Defining customized replace function
REPLACE_SEQUENCES = ['\n']

def custom_replace(s):
    for to_replace in REPLACE_SEQUENCES:
        s = s.replace(to_replace, '')
    return s.strip()

#Defining a list for the neighbourhoods 
n_list = []

#Filling the list
for i in bs.find_all(name = 'td'):
    n_list.append(custom_replace(i.get_text()))
    
#Find the last element of the table of neighbourhoods in the list
matches = [i for i,x in enumerate(n_list) if x=='Not assigned']

#Dropping elements from the list that is not part of the original wikipedia table
n_list = n_list[0:matches[-1]+1]

#Creating DataFrame from the list
n_list = np.array(n_list)
columns=['Postcode','Borough','Neighbourhood']
df_n = pd.DataFrame(np.reshape(n_list, (int(len(n_list)/3),3)),columns=columns)
df_n

#Dropping those rows where Borough is not Assigned
df_n = df_n.drop(df_n[df_n['Borough'] == 'Not assigned' ].index)

#Sorting the DataFrame
df_n.sort_values('Postcode')

#Reindexing the DataFrame
df_n = df_n.reset_index(drop=True)

#Handling those cases, where we have Borough without Neighbourhood assigned
for i in range(0,len(df_n['Neighbourhood'])):
    if df_n['Neighbourhood'][i] == 'Not assigned':
        df_n['Neighbourhood'][i] = df_n['Borough'][i]

#Combining Neighbourhood into one line that belongs to the same Postcode
duplicates = df_n['Postcode'].duplicated()
for i in range(0,len(duplicates)):
    if duplicates[i] == True:
        first_index = list(df_n['Postcode']).index(df_n['Postcode'][i])
        df_n['Neighbourhood'][first_index] += str(', ' + df_n['Neighbourhood'][i])

#Dropping rows that are duplicates in terms of postcodes
df_n = df_n[(duplicates==False)]

#Reindexing the DataFrame
df_n = df_n.reset_index(drop=True)

#Checking the dataframe
df_n
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# 5                                     Islington Avenue
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]

# %%
print(df_n.shape)
# Out:
# (103, 3)

# %% [markdown]
# ### <span style="color:darkred">Adding geospatial data</span>

# %%
# Reading Lat and Long for Postcodes
df_gsp = pd.read_csv('http://cocl.us/Geospatial_data')
df_gsp = df_gsp.rename(columns={"Postal Code": "Postcode"})
df_gsp.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
# Adding Lat and Long to df
df_n = df_n >> left_join(df_gsp, by = "Postcode")
df_n
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# ### <span style="color:darkred"> Adding the most common venue categories in each neighborhood in Toronto </span>

# %%
# Adding credentials for using Foursquare
import getpass

CLIENT_ID = getpass.getpass('Enter your Foursquare CLIENT_ID')
CLIENT_SECRET = getpass.getpass('Enter your Foursquare CLIENT_SECRET')
VERSION = '20180605'
LIMIT = 100

print('Your credentials are stored')
# Out:
# Enter your Foursquare CLIENT_ID········
# Enter your Foursquare CLIENT_SECRET········
# Your credentials are stored

# %% [markdown]
# ### <span style="color:darkred"> Filtering neighbourhoods that belongs to Toronto </span>

# %%
### <span style="color:darkred"> Filtering neighbourhoods that belongs to Toronto </span># Filtering neighbourhoods
df_n_tor = df_n >> mask(X.Borough.str.contains('Toronto') == True)
df_n_tor
# Out:
#     Postcode           Borough  \
# 2        M5A  Downtown Toronto
# 9        M5B  Downtown Toronto
# 15       M5C  Downtown Toronto
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 30       M5H  Downtown Toronto
# 31       M6H      West Toronto
# 36       M5J  Downtown Toronto
# 37       M6J      West Toronto
# 41       M4K      East Toronto
# 42       M5K  Downtown Toronto
# 43       M6K      West Toronto
# 47       M4L      East Toronto
# 48       M5L  Downtown Toronto
# 54       M4M      East Toronto
# 61       M4N   Central Toronto
# 62       M5N   Central Toronto
# 67       M4P   Central Toronto
# 68       M5P   Central Toronto
# 69       M6P      West Toronto
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 15                                      St. James Town  43.651494 -79.375418
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 30                            Adelaide, King, Richmond  43.650571 -79.384568
# 31                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 36   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 43        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 47                      The Beaches West, India Bazaar  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 54                                     Studio District  43.659526 -79.340923
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 67                                    Davisville North  43.712751 -79.390197
# 68                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
#Definging function for using API of Foursquare
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood_Latitude', 
                  'Neighbourhood_Longitude', 
                  'Venue', 
                  'Venue_Latitude', 
                  'Venue_Longitude', 
                  'Venue_Category']
    
    return(nearby_venues)

# %%
# Creating Df by adding vanues to df of Toronto's Boroughs
df_Tor_venues = getNearbyVenues(df_n_tor['Neighbourhood'], df_n_tor['Latitude'], df_n_tor['Longitude'], 500)

df_Tor_venues.head(10)
# Out:
#                Neighbourhood  Neighbourhood_Latitude  Neighbourhood_Longitude  \
# 0  Harbourfront, Regent Park                43.65426               -79.360636
# 1  Harbourfront, Regent Park                43.65426               -79.360636
# 2  Harbourfront, Regent Park                43.65426               -79.360636
# 3  Harbourfront, Regent Park                43.65426               -79.360636
# 4  Harbourfront, Regent Park                43.65426               -79.360636
# 5  Harbourfront, Regent Park                43.65426               -79.360636
# 6  Harbourfront, Regent Park                43.65426               -79.360636
# 7  Harbourfront, Regent Park                43.65426               -79.360636
# 8  Harbourfront, Regent Park                43.65426               -79.360636
# 9  Harbourfront, Regent Park                43.65426               -79.360636
#
#                                              Venue  Venue_Latitude  \
# 0                                 Roselle Desserts       43.653447
# 1                                    Tandem Coffee       43.653559
# 2  Toronto Cooper Koo Family Cherry St YMCA Centre       43.653191
# 3                              Body Blitz Spa East       43.654735
# 4                                   Impact Kitchen       43.656369
# 5                               Morning Glory Cafe       43.653947
# 6                           Figs Breakfast & Lunch       43.655675
# 7                         Dominion Pub and Kitchen       43.656919
# 8                                  Corktown Common       43.655618
# 9                 The Distillery Historic District       43.650244
#
#    Venue_Longitude        Venue_Category
# 0       -79.362017                Bakery
# 1       -79.361809           Coffee Shop
# 2       -79.357947  Gym / Fitness Center
# 3       -79.359874                   Spa
# 4       -79.356980            Restaurant
# 5       -79.361149        Breakfast Spot
# 6       -79.364503        Breakfast Spot
# 7       -79.358967                   Pub
# 8       -79.356211                  Park
# 9       -79.359323         Historic Site

# %% [markdown]
# ### <span style="color:darkred"> Encoding df containing info about nearby venues </span>

# %%
# One hot encoding for calculating frequency
toronto_onehot = pd.get_dummies(df_Tor_venues[['Venue_Category']], prefix="", prefix_sep="")

# Adding neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = df_Tor_venues['Neighbourhood']
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

#calculating frequencies
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                         Neighbourhood  Afghan Restaurant  \
# 0                            Adelaide, King, Richmond           0.000000
# 1                                         Berczy Park           0.000000
# 2        Brockton, Exhibition Place, Parkdale Village           0.000000
# 3   Business Reply Mail Processing Centre 969 Eastern           0.000000
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...           0.000000
# 5                         Cabbagetown, St. James Town           0.000000
# 6                                  Central Bay Street           0.000000
# 7           Chinatown, Grange Park, Kensington Market           0.000000
# 8                                            Christie           0.000000
# 9                                Church and Wellesley           0.011494
# 10                     Commerce Court, Victoria Hotel           0.000000
# 11                                         Davisville           0.000000
# 12                                   Davisville North           0.000000
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...           0.000000
# 14           Design Exchange, Toronto Dominion Centre           0.000000
# 15                       Dovercourt Village, Dufferin           0.000000
# 16             First Canadian Place, Underground city           0.000000
# 17                Forest Hill North, Forest Hill West           0.000000
# 18                     Harbord, University of Toronto           0.000000
# 19  Harbourfront East, Toronto Islands, Union Station           0.000000
# 20                          Harbourfront, Regent Park           0.000000
# 21                      High Park, The Junction South           0.000000
# 22                                      Lawrence Park           0.000000
# 23                           Little Portugal, Trinity           0.000000
#
# [38 rows x 241 columns]

# %% [markdown]
# ### <span style="color:darkred"> Checking the most frequent venues by Neigbourhoods </span>

# %%
df_Tor_venues_grouped = df_Tor_venues >> group_by(X.Neighbourhood, X.Venue_Category) >> summarize(Count = X.Venue_Category.count()) >> select(X.Neighbourhood, X.Venue_Category, X.Count)
df_Tor_venues_grouped = df_Tor_venues_grouped.sort_values(by=['Neighbourhood','Count'], ascending=[True, False])
df_Tor_venues_grouped
# Out:
#                        Neighbourhood                 Venue_Category  Count
# 13          Adelaide, King, Richmond                    Coffee Shop      7
# 12          Adelaide, King, Richmond                           Café      5
# 5           Adelaide, King, Richmond                            Bar      4
# 58          Adelaide, King, Richmond                Thai Restaurant      4
# 0           Adelaide, King, Richmond            American Restaurant      3
# 3           Adelaide, King, Richmond               Asian Restaurant      3
# 10          Adelaide, King, Richmond                   Burger Joint      3
# 27          Adelaide, King, Richmond                          Hotel      3
# 48          Adelaide, King, Richmond                     Restaurant      3
# 56          Adelaide, King, Richmond                     Steakhouse      3
# 57          Adelaide, King, Richmond               Sushi Restaurant      3
# 8           Adelaide, King, Richmond                 Breakfast Spot      2
# 15          Adelaide, King, Richmond                   Concert Hall      2
# 16          Adelaide, King, Richmond                 Cosmetics Shop      2
# 21          Adelaide, King, Richmond                      Gastropub      2
# 25          Adelaide, King, Richmond                            Gym      2
# 44          Adelaide, King, Richmond                    Pizza Place      2
# 60          Adelaide, King, Richmond  Vegetarian / Vegan Restaurant      2
# 1           Adelaide, King, Richmond                    Art Gallery      1
# 2           Adelaide, King, Richmond                     Art Museum      1
# 4           Adelaide, King, Richmond                         Bakery      1
# 6           Adelaide, King, Richmond                      Bookstore      1
# 7           Adelaide, King, Richmond           Brazilian Restaurant      1
# 9           Adelaide, King, Richmond                       Building      1
# 11          Adelaide, King, Richmond                  Burrito Place      1
# 14          Adelaide, King, Richmond           Colombian Restaurant      1
# 17          Adelaide, King, Richmond                  Deli / Bodega      1
# 18          Adelaide, King, Richmond               Department Store      1
# 19          Adelaide, King, Richmond              Electronics Store      1
# 20          Adelaide, King, Richmond                     Food Court      1
# ...                              ...                            ...    ...
# 1094  The Beaches West, India Bazaar                     Steakhouse      1
# 1095  The Beaches West, India Bazaar               Sushi Restaurant      1
# 1109    The Danforth West, Riverdale               Greek Restaurant      8
# 1103    The Danforth West, Riverdale                    Coffee Shop      4
# 1111    The Danforth West, Riverdale                 Ice Cream Shop      3
# 1113    The Danforth West, Riverdale             Italian Restaurant      3
# 1108    The Danforth West, Riverdale         Furniture / Home Store      2
# 1096    The Danforth West, Riverdale            American Restaurant      1
# 1097    The Danforth West, Riverdale                         Bakery      1
# 1098    The Danforth West, Riverdale                      Bookstore      1
# 1099    The Danforth West, Riverdale                        Brewery      1
# 1100    The Danforth West, Riverdale                Bubble Tea Shop      1
# 1101    The Danforth West, Riverdale                           Café      1
# 1102    The Danforth West, Riverdale           Caribbean Restaurant      1
# 1104    The Danforth West, Riverdale                 Cosmetics Shop      1
# 1105    The Danforth West, Riverdale                   Dessert Shop      1
# 1106    The Danforth West, Riverdale                          Diner      1
# 1107    The Danforth West, Riverdale        Fruit & Vegetable Store      1
# 1110    The Danforth West, Riverdale                  Grocery Store      1
# 1112    The Danforth West, Riverdale              Indian Restaurant      1
# 1114    The Danforth West, Riverdale                      Juice Bar      1
# 1115    The Danforth West, Riverdale                   Liquor Store      1
# 1116    The Danforth West, Riverdale                         Lounge      1
# 1117    The Danforth West, Riverdale                    Pizza Place      1
# 1118    The Danforth West, Riverdale                            Pub      1
# 1119    The Danforth West, Riverdale                     Restaurant      1
# 1120    The Danforth West, Riverdale                            Spa      1
# 1121    The Danforth West, Riverdale                     Sports Bar      1
# 1122    The Danforth West, Riverdale                          Trail      1
# 1123    The Danforth West, Riverdale                    Yoga Studio      1
#
# [1124 rows x 3 columns]

# %%
# Selecting the first 10 most frequent Vanue Category by Neighbourhood
df_venue = pd.DataFrame() #creates a new dataframe that's empty

for element in df_Tor_venues_grouped.Neighbourhood.unique():
    df_container = df_Tor_venues_grouped >> mask(X.Neighbourhood == element)
    if len(df_container) < 10:
        df_venue = df_venue.append(df_container)
    if len(df_container) >= 10:
        df_venue = df_venue.append(df_container.head(10))
df_venue
# Out:
#                                      Neighbourhood          Venue_Category  \
# 13                        Adelaide, King, Richmond             Coffee Shop
# 12                        Adelaide, King, Richmond                    Café
# 5                         Adelaide, King, Richmond                     Bar
# 58                        Adelaide, King, Richmond         Thai Restaurant
# 0                         Adelaide, King, Richmond     American Restaurant
# 3                         Adelaide, King, Richmond        Asian Restaurant
# 10                        Adelaide, King, Richmond            Burger Joint
# 27                        Adelaide, King, Richmond                   Hotel
# 48                        Adelaide, King, Richmond              Restaurant
# 56                        Adelaide, King, Richmond              Steakhouse
# 76                                     Berczy Park             Coffee Shop
# 75                                     Berczy Park            Cocktail Bar
# 66                                     Berczy Park                  Bakery
# 69                                     Berczy Park                Beer Bar
# 72                                     Berczy Park                    Café
# 73                                     Berczy Park             Cheese Shop
# 82                                     Berczy Park          Farmers Market
# 99                                     Berczy Park      Seafood Restaurant
# 102                                    Berczy Park              Steakhouse
# 63                                     Berczy Park             Art Gallery
# 111   Brockton, Exhibition Place, Parkdale Village                    Café
# 107   Brockton, Exhibition Place, Parkdale Village                  Bakery
# 109   Brockton, Exhibition Place, Parkdale Village          Breakfast Spot
# 114   Brockton, Exhibition Place, Parkdale Village             Coffee Shop
# 127   Brockton, Exhibition Place, Parkdale Village             Yoga Studio
# 108   Brockton, Exhibition Place, Parkdale Village                     Bar
# 110   Brockton, Exhibition Place, Parkdale Village           Burrito Place
# 112   Brockton, Exhibition Place, Parkdale Village    Caribbean Restaurant
# 113   Brockton, Exhibition Place, Parkdale Village            Climbing Gym
# 115   Brockton, Exhibition Place, Parkdale Village       Convenience Store
# ...                                            ...                     ...
# 1059           The Annex, North Midtown, Yorkville            Burger Joint
# 1062           The Annex, North Midtown, Yorkville          Cosmetics Shop
# 1063           The Annex, North Midtown, Yorkville          History Museum
# 8        3      M5H  Downtown Toronto  43.650571 -79.384568
# 9        3      M5H  Downtown Toronto  43.650571 -79.384568
# 10       4      M5E  Downtown Toronto  43.644771 -79.373306
# 11       3      M5E  Downtown Toronto  43.644771 -79.373306
# 12       2      M5E  Downtown Toronto  43.644771 -79.373306
# 13       2      M5E  Downtown Toronto  43.644771 -79.373306
# 14       2      M5E  Downtown Toronto  43.644771 -79.373306
# 15       2      M5E  Downtown Toronto  43.644771 -79.373306
# 16       2      M5E  Downtown Toronto  43.644771 -79.373306
# 17       2      M5E  Downtown Toronto  43.644771 -79.373306
# 18       2      M5E  Downtown Toronto  43.644771 -79.373306
# 19       1      M5E  Downtown Toronto  43.644771 -79.373306
# 20       3      M6K      West Toronto  43.636847 -79.428191
# 21       2      M6K      West Toronto  43.636847 -79.428191
# 22       2      M6K      West Toronto  43.636847 -79.428191
# 23       2      M6K      West Toronto  43.636847 -79.428191
# 24       2      M6K      West Toronto  43.636847 -79.428191
# 25       1      M6K      West Toronto  43.636847 -79.428191
# 26       1      M6K      West Toronto  43.636847 -79.428191
# 27       1      M6K      West Toronto  43.636847 -79.428191
# 28       1      M6K      West Toronto  43.636847 -79.428191
# 29       1      M6K      West Toronto  43.636847 -79.428191
# ..     ...      ...               ...        ...        ...
# 313      1      M5R   Central Toronto  43.672710 -79.405678
# 314      1      M5R   Central Toronto  43.672710 -79.405678
# 315      1      M5R   Central Toronto  43.672710 -79.405678
# 316      1      M5R   Central Toronto  43.672710 -79.405678
# 317      1      M5R   Central Toronto  43.672710 -79.405678
# 318      1      M4E      East Toronto  43.676357 -79.293031
# 319      1      M4E      East Toronto  43.676357 -79.293031
# 320      1      M4E      East Toronto  43.676357 -79.293031
# 321      1      M4E      East Toronto  43.676357 -79.293031
# 322      1      M4E      East Toronto  43.676357 -79.293031
# 323      1      M4L      East Toronto  43.668999 -79.315572
# 324      1      M4L      East Toronto  43.668999 -79.315572
# 325      1      M4L      East Toronto  43.668999 -79.315572
# 326      1      M4L      East Toronto  43.668999 -79.315572
# 327      1      M4L      East Toronto  43.668999 -79.315572
# 328      1      M4L      East Toronto  43.668999 -79.315572
# 329      1      M4L      East Toronto  43.668999 -79.315572
# 330      1      M4L      East Toronto  43.668999 -79.315572
# 331      1      M4L      East Toronto  43.668999 -79.315572
# 332      1      M4L      East Toronto  43.668999 -79.315572
# 333      8      M4K      East Toronto  43.679557 -79.352188
# 334      4      M4K      East Toronto  43.679557 -79.352188
# 335      3      M4K      East Toronto  43.679557 -79.352188
# 336      3      M4K      East Toronto  43.679557 -79.352188
# 337      2      M4K      East Toronto  43.679557 -79.352188
# 338      1      M4K      East Toronto  43.679557 -79.352188
# 339      1      M4K      East Toronto  43.679557 -79.352188
# 340      1      M4K      East Toronto  43.679557 -79.352188
# 341      1      M4K      East Toronto  43.679557 -79.352188
# 342      1      M4K      East Toronto  43.679557 -79.352188
#
# [343 rows x 7 columns]

# %%
### <span style="color:darkred"> Clustering neighbourhoods based on most frequent venue types </span>

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:100]
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3,
#        0, 3, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 3, 1, 3, 3])

# %%
# Creating dataframe for storing cluster label of Neighbourhoods
toronto_clusters = toronto_grouped >> mutate(Clusters = kmeans.labels_) >> select(X.Neighbourhood, X.Clusters)
toronto_clusters
# Out:
#                                         Neighbourhood  Clusters
# 0                            Adelaide, King, Richmond         3
# 1                                         Berczy Park         3
# 2        Brockton, Exhibition Place, Parkdale Village         3
# 3   Business Reply Mail Processing Centre 969 Eastern         3
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...         3
# 5                         Cabbagetown, St. James Town         3
# 6                                  Central Bay Street         3
# 7           Chinatown, Grange Park, Kensington Market         3
# 8                                            Christie         3
# 9                                Church and Wellesley         3
# 10                     Commerce Court, Victoria Hotel         3
# 11                                         Davisville         3
# 12                                   Davisville North         3
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...         3
# 14           Design Exchange, Toronto Dominion Centre         3
# 15                       Dovercourt Village, Dufferin         3
# 16             First Canadian Place, Underground city         3
# 17                Forest Hill North, Forest Hill West         1
# 18                     Harbord, University of Toronto         3
# 19  Harbourfront East, Toronto Islands, Union Station         3
# 20                          Harbourfront, Regent Park         3
# 21                      High Park, The Junction South         3
# 22                                      Lawrence Park         0
# 23                           Little Portugal, Trinity         3
# 24                        Moore Park, Summerhill East         3
# 25                                 North Toronto West         3
# 26                             Parkdale, Roncesvalles         3
# 27                                           Rosedale         1
# 28                                           Roselawn         2
# 29                                 Runnymede, Swansea         3
# 30                           Ryerson, Garden District         3
# 31                                     St. James Town         3
# 32                    Stn A PO Boxes 25 The Esplanade         3
# 33                                    Studio District         3
# 34                The Annex, North Midtown, Yorkville         3
# 35                                        The Beaches         1
# 36                     The Beaches West, India Bazaar         3
# 37                       The Danforth West, Riverdale         3

# %%
# Adding clusters to Df venue
df_venue = df_venue >> left_join(toronto_clusters, by="Neighbourhood")
df_venue
# Out:
#                                     Neighbourhood          Venue_Category  \
# 0                        Adelaide, King, Richmond             Coffee Shop
# 1                        Adelaide, King, Richmond                    Café
# 2                        Adelaide, King, Richmond                     Bar
# 3                        Adelaide, King, Richmond         Thai Restaurant
# 4                        Adelaide, King, Richmond     American Restaurant
# 5                        Adelaide, King, Richmond        Asian Restaurant
# 6                        Adelaide, King, Richmond            Burger Joint
# 7                        Adelaide, King, Richmond                   Hotel
# 8                        Adelaide, King, Richmond              Restaurant
# 9                        Adelaide, King, Richmond              Steakhouse
# 10                                    Berczy Park             Coffee Shop
# 11                                    Berczy Park            Cocktail Bar
# 12                                    Berczy Park                  Bakery
# 13                                    Berczy Park                Beer Bar
# 14                                    Berczy Park                    Café
# 15                                    Berczy Park             Cheese Shop
# 16                                    Berczy Park          Farmers Market
# 17                                    Berczy Park      Seafood Restaurant
# 18                                    Berczy Park              Steakhouse
# 19                                    Berczy Park             Art Gallery
# 20   Brockton, Exhibition Place, Parkdale Village                    Café
# 21   Brockton, Exhibition Place, Parkdale Village                  Bakery
# 22   Brockton, Exhibition Place, Parkdale Village          Breakfast Spot
# 23   Brockton, Exhibition Place, Parkdale Village             Coffee Shop
# 16       2      M5E  Downtown Toronto  43.644771 -79.373306         3
# 17       2      M5E  Downtown Toronto  43.644771 -79.373306         3
# 18       2      M5E  Downtown Toronto  43.644771 -79.373306         3
# 19       1      M5E  Downtown Toronto  43.644771 -79.373306         3
# 20       3      M6K      West Toronto  43.636847 -79.428191         3
# 21       2      M6K      West Toronto  43.636847 -79.428191         3
# 22       2      M6K      West Toronto  43.636847 -79.428191         3
# 23       2      M6K      West Toronto  43.636847 -79.428191         3
# 24       2      M6K      West Toronto  43.636847 -79.428191         3
# 25       1      M6K      West Toronto  43.636847 -79.428191         3
# 26       1      M6K      West Toronto  43.636847 -79.428191         3
# 27       1      M6K      West Toronto  43.636847 -79.428191         3
# 28       1      M6K      West Toronto  43.636847 -79.428191         3
# 29       1      M6K      West Toronto  43.636847 -79.428191         3
# ..     ...      ...               ...        ...        ...       ...
# 313      1      M5R   Central Toronto  43.672710 -79.405678         3
# 314      1      M5R   Central Toronto  43.672710 -79.405678         3
# 315      1      M5R   Central Toronto  43.672710 -79.405678         3
# 316      1      M5R   Central Toronto  43.672710 -79.405678         3
# 317      1      M5R   Central Toronto  43.672710 -79.405678         3
# 318      1      M4E      East Toronto  43.676357 -79.293031         1
# 319      1      M4E      East Toronto  43.676357 -79.293031         1
# 320      1      M4E      East Toronto  43.676357 -79.293031         1
# 321      1      M4E      East Toronto  43.676357 -79.293031         1
# 322      1      M4E      East Toronto  43.676357 -79.293031         1
# 323      1      M4L      East Toronto  43.668999 -79.315572         3
# 324      1      M4L      East Toronto  43.668999 -79.315572         3
# 325      1      M4L      East Toronto  43.668999 -79.315572         3
# 326      1      M4L      East Toronto  43.668999 -79.315572         3
# 327      1      M4L      East Toronto  43.668999 -79.315572         3
# 328      1      M4L      East Toronto  43.668999 -79.315572         3
# 329      1      M4L      East Toronto  43.668999 -79.315572         3
# 330      1      M4L      East Toronto  43.668999 -79.315572         3
# 331      1      M4L      East Toronto  43.668999 -79.315572         3
# 332      1      M4L      East Toronto  43.668999 -79.315572         3
# 333      8      M4K      East Toronto  43.679557 -79.352188         3
# 334      4      M4K      East Toronto  43.679557 -79.352188         3
# 335      3      M4K      East Toronto  43.679557 -79.352188         3
# 336      3      M4K      East Toronto  43.679557 -79.352188         3
# 337      2      M4K      East Toronto  43.679557 -79.352188         3
# 338      1      M4K      East Toronto  43.679557 -79.352188         3
# 339      1      M4K      East Toronto  43.679557 -79.352188         3
# 340      1      M4K      East Toronto  43.679557 -79.352188         3
# 341      1      M4K      East Toronto  43.679557 -79.352188         3
# 342      1      M4K      East Toronto  43.679557 -79.352188         3
#
# [343 rows x 8 columns]

# %%
# Creating data_frame for mapping
df_toronto = df_venue >> drop(X.Venue_Category, X.Count) >> distinct(X.Neighbourhood)
df_toronto = df_toronto.reset_index(drop=True)
df_toronto
# Out:
#                                         Neighbourhood Postcode  \
# 0                            Adelaide, King, Richmond      M5H
# 1                                         Berczy Park      M5E
# 2        Brockton, Exhibition Place, Parkdale Village      M6K
# 3   Business Reply Mail Processing Centre 969 Eastern      M7Y
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...      M5V
# 5                         Cabbagetown, St. James Town      M4X
# 6                                  Central Bay Street      M5G
# 7           Chinatown, Grange Park, Kensington Market      M5T
# 8                                            Christie      M6G
# 9                                Church and Wellesley      M4Y
# 10                     Commerce Court, Victoria Hotel      M5L
# 11                                         Davisville      M4S
# 12                                   Davisville North      M4P
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...      M4V
# 14           Design Exchange, Toronto Dominion Centre      M5K
# 15                       Dovercourt Village, Dufferin      M6H
# 16             First Canadian Place, Underground city      M5X
# 17                Forest Hill North, Forest Hill West      M5P
# 18                     Harbord, University of Toronto      M5S
# 19  Harbourfront East, Toronto Islands, Union Station      M5J
# 20                          Harbourfront, Regent Park      M5A
# 21                      High Park, The Junction South      M6P
# 22                                      Lawrence Park      M4N
# 23                           Little Portugal, Trinity      M6J
# 24                        Moore Park, Summerhill East      M4T
# 25                                 North Toronto West      M4R
# 26                             Parkdale, Roncesvalles      M6R
# 27                                           Rosedale      M4W
# 28                                           Roselawn      M5N
# 29                                 Runnymede, Swansea      M6S
# 30                           Ryerson, Garden District      M5B
# 31                                     St. James Town      M5C
# 32                    Stn A PO Boxes 25 The Esplanade      M5W
# 33                                    Studio District      M4M
# 34                The Annex, North Midtown, Yorkville      M5R
# 35                                        The Beaches      M4E
# 36                     The Beaches West, India Bazaar      M4L
# 37                       The Danforth West, Riverdale      M4K
#
#              Borough   Latitude  Longitude  Clusters
# 0   Downtown Toronto  43.650571 -79.384568         3
# 1   Downtown Toronto  43.644771 -79.373306         3
# 2       West Toronto  43.636847 -79.428191         3
# 3       East Toronto  43.662744 -79.321558         3
# 4   Downtown Toronto  43.628947 -79.394420         3
# 5   Downtown Toronto  43.667967 -79.367675         3
# 6   Downtown Toronto  43.657952 -79.387383         3
# 7   Downtown Toronto  43.653206 -79.400049         3
# 8   Downtown Toronto  43.669542 -79.422564         3
# 9   Downtown Toronto  43.665860 -79.383160         3
# 10  Downtown Toronto  43.648198 -79.379817         3
# 11   Central Toronto  43.704324 -79.388790         3
# 12   Central Toronto  43.712751 -79.390197         3
# 13   Central Toronto  43.686412 -79.400049         3
# 14  Downtown Toronto  43.647177 -79.381576         3
# 15      West Toronto  43.669005 -79.442259         3
# 16  Downtown Toronto  43.648429 -79.382280         3
# 17   Central Toronto  43.696948 -79.411307         1
# 18  Downtown Toronto  43.662696 -79.400049         3
# 19  Downtown Toronto  43.640816 -79.381752         3
# 20  Downtown Toronto  43.654260 -79.360636         3
# 21      West Toronto  43.661608 -79.464763         3
# 22   Central Toronto  43.728020 -79.388790         0
# 23      West Toronto  43.647927 -79.419750         3
# 24   Central Toronto  43.689574 -79.383160         3
# 25   Central Toronto  43.715383 -79.405678         3
# 26      West Toronto  43.648960 -79.456325         3
# 27  Downtown Toronto  43.679563 -79.377529         1
# 28   Central Toronto  43.711695 -79.416936         2
# 29      West Toronto  43.651571 -79.484450         3
# 30  Downtown Toronto  43.657162 -79.378937         3
# 31  Downtown Toronto  43.651494 -79.375418         3
# 32  Downtown Toronto  43.646435 -79.374846         3
# 33      East Toronto  43.659526 -79.340923         3
# 34   Central Toronto  43.672710 -79.405678         3
# 35      East Toronto  43.676357 -79.293031         1
# 36      East Toronto  43.668999 -79.315572         3
# 37      East Toronto  43.679557 -79.352188         3

# %% [markdown]
# ### <span style="color:darkred"> Mapping clusters </span>

# %%
# Finding geospatial data of Toronto
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronot are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronot are 43.653963, -79.387207.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Neighbourhood'], df_toronto['Clusters']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### <span style="color:darkred"> Exploring Clusters </span>

# %%
# Checking most frequent venues in Cluster 1
df_venue >> mask(X.Clusters == 0) >> select(X.Venue_Category) >> distinct(X.Venue_Category)
# Out:
#     Venue_Category
# 215       Bus Line
# 216           Park
# 217    Swim School

# %%
# Checking most frequent venues in Cluster 2
df_venue >> mask(X.Clusters == 1) >> select(X.Venue_Category) >> distinct(X.Venue_Category)
# Out:
#            Venue_Category
# 170              Bus Line
# 171         Jewelry Store
# 172                  Park
# 173      Sushi Restaurant
# 174                 Trail
# 253              Building
# 254            Playground
# 318     Health Food Store
# 319          Neighborhood
# 320  Other Great Outdoors
# 321                   Pub

# %%
# Checking most frequent venues in Cluster 3
df_venue >> mask(X.Clusters == 2) >> select(X.Venue_Category) >> distinct(X.Venue_Category)
# Out:
#     Venue_Category
# 256         Garden
# 257   Home Service

# %%
# Checking most frequent venues in Cluster 4
df_venue >> mask(X.Clusters == 3) >> select(X.Venue_Category) >> distinct(X.Venue_Category)
# Out:
#                   Venue_Category
# 0                    Coffee Shop
# 1                           Café
# 2                            Bar
# 3                Thai Restaurant
# 4            American Restaurant
# 5               Asian Restaurant
# 6                   Burger Joint
# 7                          Hotel
# 8                     Restaurant
# 9                     Steakhouse
# 11                  Cocktail Bar
# 12                        Bakery
# 13                      Beer Bar
# 15                   Cheese Shop
# 16                Farmers Market
# 17            Seafood Restaurant
# 19                   Art Gallery
# 22                Breakfast Spot
# 24                   Yoga Studio
# 26                 Burrito Place
# 27          Caribbean Restaurant
# 28                  Climbing Gym
# 29             Convenience Store
# 30            Light Rail Station
# 31                 Auto Workshop
# 32                       Brewery
# 34                       Butcher
# 35                    Comic Shop
# 37          Fast Food Restaurant
# 38                        Garden
# ..                           ...
# 151                     Pharmacy
# 152                  Supermarket
# 158         Gym / Fitness Center
# 159    Middle Eastern Restaurant
# 178                    Bookstore
# 186                     Aquarium
# 192               Scenic Lookout
# 203                      Theater
# 204                 Antique Shop
# 212    Cajun / Creole Restaurant
# 214               Discount Store
# 220                  Men's Store
# 224            French Restaurant
# 225      New American Restaurant
# 229                   Playground
# 231                 Tennis Court
# 233          Sporting Goods Shop
# 241                Metro Station
# 243                    Gift Shop
# 248             Cuban Restaurant
# 250                      Dog Run
# 251  Eastern European Restaurant
# 270               Cosmetics Shop
# 312                    BBQ Joint
# 315               History Museum
# 316            Indian Restaurant
# 317            Jewish Restaurant
# 328            Fish & Chips Shop
# 333             Greek Restaurant
# 337       Furniture / Home Store
#
# [103 rows x 1 columns]
